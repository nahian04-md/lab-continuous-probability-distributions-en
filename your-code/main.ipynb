# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# your code here
from scipy.stats import uniform


a = 0  # lower bound
b = 10 # upper bound

# loc = a (start point), scale = b-a (range)
random_numbers = uniform.rvs(loc=a, scale=b-a, size=1000)

print(f"First 20 random numbers: {random_numbers[:20]}")
# Out:
# First 20 random numbers: [5.43961291 3.37121502 8.96039761 2.38032832 7.45377691 8.42327988
#  4.79394991 5.93253698 9.71327707 7.39924053 7.81702681 1.70816248
#  5.40525808 9.13389277 3.11064557 4.26902831 9.94594937 8.36943855
#  9.55585671 3.85264739]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
import numpy as np

def gen_random_uni(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, size=count)

# %%
# your code here
nums1_ru = gen_random_uni(10, 15,100)
print(nums)
# Out:
# [14 13 14 10 11 10 10 14 11 10 13 14 13 11 14 14 12 10 11 14 11 13 14 11
#  10 11 12 11 11 13 11 11 14 14 11 12 10 11 10 11 11 12 14 11 10 11 14 14
#  12 10 14 14 10 11 11 10 14 13 13 14 13 11 12 14 13 11 14 10 13 11 12 13
#  14 13 13 13 12 10 12 11 13 12 11 11 13 12 14 12 14 10 14 13 13 11 10 10
#  11 10 11 11]

# %%
# your code here
nums2_ru = gen_random_uni(10, 60, 1000)
print(nums2)
# Out:
# [46.14658663 47.82215285 21.04443033 45.32327483 44.70973864 51.16768756
#  47.14548933 27.91729876 22.40785388 31.47316396 45.48712867 40.24238466
#  18.54615367 18.78754599 37.94957968 36.92467711 21.53422867 40.4519689
#  54.33256028 36.39448445 27.86186131 28.47989397 46.70454056 55.83331423
#  24.45456895 36.61065256 33.88711084 36.30355823 59.43423209 56.42919235
#  54.74205938 25.10025488 17.15969307 39.88527608 27.03989525 39.00062886
#  22.05525169 22.06829713 20.24857001 13.67176072 49.29261681 50.22260273
#  10.92802679 33.85934638 28.44674399 22.66093349 41.35360775 34.240056
#  56.16490409 17.23538847 52.50735748 26.60456951 58.320071   45.24643399
#  35.39108752 48.46270399 36.4567664  47.83008494 18.46925119 12.21441836
#  19.19064655 37.19820342 41.87220481 29.08053214 51.29330257 13.81765641
#  54.67503738 21.69470541 20.51144579 15.21661126 36.7062498  19.94823501
#  27.54538812 41.65467126 12.53407173 39.37357821 59.59232921 58.60540179
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# First histogram
axes[0].hist(nums1_ru, bins=10, color='skyblue', edgecolor='black')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Count')
axes[0].set_title('Uniform Distribution (10, 15, 100)')
axes[0].grid(axis='y', alpha=0.3)

# Second histogram
axes[1].hist(nums2_ru, bins=10, color='lightcoral', edgecolor='black')
axes[1].set_xlabel('Value')
axes[1].set_ylabel('Count')
axes[1].set_title('Uniform Distribution (10, 60, 1000)')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
The pattern of data is the same for both data sets, only for the second one the values are more spread out due to the larger range (10 to 60) and higher count (1000).

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here
import numpy as np
import matplotlib.pyplot as plt

def gen_normal(mean, std, count):
    return np.random.normal(loc=mean, scale=std, size=count)

# %%
# your code here
nums1_n = gen_normal(10, 1, 1000)
print(nums1)
# Out:
# [13.77752534 14.09256224 11.67106906 12.70318908 13.35427849 13.22143131
#  14.23229533 12.52134525 11.77558587 10.24774747 13.64697463 12.84629951
#  11.62508041 14.41774766 10.11861642 14.0274448  12.99009469 14.52217968
#  13.8395683  14.98571258 14.09532596 10.21207135 11.3615429  14.45781861
#  14.47261675 13.16348454 11.63625563 14.55289026 10.42795856 13.62796814
#  11.6410437  12.46407161 13.88229379 11.47836633 11.10521037 10.4751492
#  10.67988379 13.73494902 10.04706371 12.03446605 11.31591805 10.918648
#  13.52885646 12.82671661 12.56576523 11.60734438 13.73546818 10.06873042
#  11.58677863 11.74287353 11.17832285 14.8405367  14.4592629  12.90245096
#  13.35512255 13.4840032  13.63284922 10.05615648 10.85957876 11.19589262
#  10.7850751  11.27379062 13.05156209 10.61036429 10.89465838 13.85990085
#  11.49143441 13.19613431 11.62383243 11.70524596 12.83353896 11.91148407
#  10.25263644 10.04011613 11.96007853 12.01498893 11.15096645 14.87729435
# ...

# %%
# your code here
nums2_n = gen_normal(10, 50, 1000)
print(nums2)
# Out:
# [46.14658663 47.82215285 21.04443033 45.32327483 44.70973864 51.16768756
#  47.14548933 27.91729876 22.40785388 31.47316396 45.48712867 40.24238466
#  18.54615367 18.78754599 37.94957968 36.92467711 21.53422867 40.4519689
#  54.33256028 36.39448445 27.86186131 28.47989397 46.70454056 55.83331423
#  24.45456895 36.61065256 33.88711084 36.30355823 59.43423209 56.42919235
#  54.74205938 25.10025488 17.15969307 39.88527608 27.03989525 39.00062886
#  22.05525169 22.06829713 20.24857001 13.67176072 49.29261681 50.22260273
#  10.92802679 33.85934638 28.44674399 22.66093349 41.35360775 34.240056
#  56.16490409 17.23538847 52.50735748 26.60456951 58.320071   45.24643399
#  35.39108752 48.46270399 36.4567664  47.83008494 18.46925119 12.21441836
#  19.19064655 37.19820342 41.87220481 29.08053214 51.29330257 13.81765641
#  54.67503738 21.69470541 20.51144579 15.21661126 36.7062498  19.94823501
#  27.54538812 41.65467126 12.53407173 39.37357821 59.59232921 58.60540179
# ...

# %%
# your code here
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
axes[0].hist(nums1_n, bins=30, color='steelblue', edgecolor='black')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Count')
axes[0].set_title('Normal Distribution (mean=10, std=1)')
axes[0].grid(axis='y', alpha=0.3)

# Second histogram (mean=10, std=50)
axes[1].hist(nums2_n, bins=30, color='steelblue', edgecolor='black')
axes[1].set_xlabel('Value')
axes[1].set_ylabel('Count')
axes[1].set_title('Normal Distribution (mean=10, std=50)')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Your answer here
# The pattern of data is similar, only for the second one the values are more spread out due the standard deviation being significant larger.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# your code here
vehicle = pd.read_csv(r"C:\Users\nahia\OneDrive\Escritorio\Ironhack_Bootcamp\Woche_Vier\lab-continuous-probability-distributions-en\your-code\vehicles.csv")

# %%
vehicle.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
vehicle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
vehicle.shape
# Out:
# (35952, 15)

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicle["Fuel Barrels/Year"]
# Out:
# 0        19.388824
# 1        25.354615
# 2        20.600625
# 3        25.354615
# 4        20.600625
#            ...
# 35947     9.155833
# 35948     9.155833
# 35949     9.155833
# 35950     9.155833
# 35951     9.417429
# Name: Fuel Barrels/Year, Length: 35952, dtype: float64

# %%
# your code here
# plot histogram of 'Fuel Barrels/Year' column
plt.figure(figsize=(10, 6))
plt.hist(vehicle["Fuel Barrels/Year"], bins=30, color='steelblue', edgecolor='black')
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Count')
plt.title('Distribution of Fuel Barrels/Year')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
data = vehicle["Fuel Barrels/Year"]

# 2. Trim outliers using 1st and 99th percentiles
lower = np.percentile(data, 1)
upper = np.percentile(data, 99)
data_trimmed = data[(data >= lower) & (data <= upper)]

# 3. Shapiro-Wilk test on trimmed data
stat, p = shapiro(data_trimmed)
print("Shapiro-Wilk Test:")
print("Statistic:", stat)
print("p-value:", p)

if p > 0.05:
    print("The data appears to be normally distributed (fail to reject H0).")
else:
    print("The data does NOT appear to be normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test:
# Statistic: 0.9683877500514545
# p-value: 7.929295985215179e-64
# The data does NOT appear to be normally distributed (reject H0).
# c:\Users\nahia\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 35424.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here

plt.figure(figsize=(10, 6))
plt.hist(vehicle["CO2 Emission Grams/Mile"], bins=30, color='steelblue', edgecolor='black')
plt.xlabel("CO2 Emission Grams/Mile")
plt.ylabel('Count')
plt.title('Distribution of CO2 Emission Grams/Mile')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# your code here
data1 = vehicle["CO2 Emission Grams/Mile"]

# 2. Trim outliers using 1st and 99th percentiles
lower = np.percentile(data1, 40)
upper = np.percentile(data1, 60)
data1_trimmed = data1[(data1 >= lower) & (data1 <= upper)]


# 3. Shapiro-Wilk test on trimmed data
stat, p = shapiro(data1_trimmed)
print("Shapiro-Wilk Test:")
print("Statistic:", stat)
print("p-value:", p)

if p > 0.05:
    print("The data appears to be normally distributed (fail to reject H0).")
else:
    print("The data does NOT appear to be normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test:
# Statistic: 0.8229125282085349
# p-value: 3.0351179210952034e-73
# The data does NOT appear to be normally distributed (reject H0).
# c:\Users\nahia\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 9680.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# 3. Combined MPG

# %%
# your code here

plt.figure(figsize=(10, 6))
plt.hist(vehicle["Combined MPG"], bins=30, color='steelblue', edgecolor='black')
plt.xlabel("Combined MPG")
plt.ylabel('Count')
plt.title('Distribution of Combined MPG')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# your code here
# your code here
data2 = vehicle["Combined MPG"]

# 2. Trim outliers using 1st and 99th percentiles
lower = np.percentile(data2, 30)
upper = np.percentile(data2, 50)
data2_trimmed = data2[(data2 >= lower) & (data2 <= upper)]


# 3. Shapiro-Wilk test on trimmed data
stat, p = shapiro(data2_trimmed)
print("Shapiro-Wilk Test:")
print("Statistic:", stat)
print("p-value:", p)

if p > 0.05:
    print("The data appears to be normally distributed (fail to reject H0).")
else:
    print("The data does NOT appear to be normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test:
# Statistic: 0.8009160049156219
# p-value: 9.758610824546372e-75
# The data does NOT appear to be normally distributed (reject H0).
# c:\Users\nahia\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 9261.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %% [markdown]
# Using percentiles i can tell no one of the variables have a normal distribution.

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
import numpy as np
import matplotlib.pyplot as plt

def gen_exp(mean=10, size=1000):
    return np.random.exponential(scale=mean, size=size)

# %%
gen_exp_example = gen_exp(size=1000, mean=10)
print(gen_exp_example[:10])
# Out:
# [22.1435081   0.71804862  5.0019116   3.02209382 13.31794588  8.3620715
#  11.61341882  5.14124174  8.11786175 10.08878028]

# %%
gen_exp_example1 = gen_exp(size=10, mean=10)
print(gen_exp_example1[:10])
# Out:
# [ 3.07374657 19.51095559 41.37154216 18.85417165 15.22152484  3.81865273
#  10.5794526   7.59722302 23.69947953 32.10300083]

# %%
gen_exp_example2 = gen_exp(size=100, mean=10)
print(gen_exp_example2[:10])
# Out:
# [ 4.63280479  8.06310625  7.12076943 16.68297259  0.33070821 18.88894465
#  10.03397267 17.34919201  3.49363695 25.39191527]

# %%
plt.figure(figsize=(10, 6))
plt.hist(gen_exp_example1, bins=100, color='steelblue', edgecolor='black')
plt.xlabel("mean=10, size=10")
plt.ylabel('Count')
plt.title('chart1')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(gen_exp_example2, bins=100, color='steelblue', edgecolor='black')
plt.xlabel("mean=10, size=100")
plt.ylabel('Count')
plt.title('chart2')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
significantly different

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your code here
import numpy as np

# Given parameters
mean = 10
lam = 1 / mean  # λ = 1/mean

# Time threshold
x = 15

# Probability P(X < 15)
p = 1 - np.exp(-lam * x)
print(f"P(X < {x}) = {p:.4f}")
# Out:
# P(X < 15) = 0.7769

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your code here

# your code here
import numpy as np

# Given parameters
mean = 10
lam = 1 / mean  # λ = 1/mean

# Time threshold
x = 15

# Probability P(X < 15)
p = np.exp(-lam * x)
print(f"P(X > {x}) = {p:.4f}")
# Out:
# P(X > 15) = 0.2231
